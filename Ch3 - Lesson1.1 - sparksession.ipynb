# %% [markdown]
# 1. How to create a Spark session?

# %%
# importing Sparksession from pyspark.sql
from pyspark.sql import SparkSession
# creating sparksession
spark_session = SparkSession.builder.getOrCreate()

# %%
# Checking if the sparksession is created and with what version.
spark_session.version
# Out:
# '4.0.0'

# %% [markdown]
# 2. What is pre-created Spark session

# %%
# The spark session is created automatically when you create a notebook in databricks
spark.version
# This spark session was pre created by databricks, notice that the version type is the same as the spark_session version
# Out:
# '4.0.0'

# %% [markdown]
# 3. How to use SparkSession to read table data?

# %%
# Reading the table from dev.spark_db.diamonds and storing it in a dataframe
df = spark.read.table("dev.spark_db.diamonds")
# showing   the dataframe
df.show()
# Out:
# +-----+-------+-----+---------+-----+-----+
# |carat|clarity|color|      cut|depth|price|
# +-----+-------+-----+---------+-----+-----+
# | 0.23|    SI2|    E|    Ideal| 61.5|326.0|
# | 0.21|    SI1|    E|  Premium| 59.8|326.0|
# | 0.23|    VS1|    E|     Good| 56.9|327.0|
# | 0.29|    VS2|    I|  Premium| 62.4|334.0|
# | 0.31|    SI2|    J|     Good| 63.3|335.0|
# | 0.24|   VVS2|    J|Very Good| 62.8|336.0|
# | 0.24|   VVS1|    I|Very Good| 62.3|336.0|
# | 0.26|    SI1|    H|Very Good| 61.9|337.0|
# | 0.22|    VS2|    E|     Fair| 65.1|337.0|
# | 0.23|    VS1|    H|Very Good| 59.4|338.0|
# |  0.3|    SI1|    J|     Good| 64.0|339.0|
# | 0.23|    VS1|    J|    Ideal| 62.8|340.0|
# | 0.22|    SI1|    F|  Premium| 60.4|342.0|
# | 0.31|    SI2|    J|    Ideal| 62.2|344.0|
# |  0.2|    SI2|    E|  Premium| 60.2|345.0|
# | 0.32|     I1|    E|  Premium| 60.9|345.0|
# |  0.3|    SI2|    I|    Ideal| 62.0|348.0|
# |  0.3|    SI1|    J|     Good| 63.4|351.0|
# ...

# %%
# or we can use a rapper method .display() to display a more clarified dataframe
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
